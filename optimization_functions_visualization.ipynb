# %%
import functions
import numpy as np
# %matplotlib inline

f_list = [functions.Ackley(),
     functions.Griewank(),
     functions.Beale(),
     functions.Booth(),
     functions.Rothyp()]


for f in f_list:
    f.plot()
# Out:
# Beale function is 2 dimensional, therefore, it cannot be displayed in a 2d plot
# Booth function is 2 dimensional, therefore, it cannot be displayed in a 2d plot
