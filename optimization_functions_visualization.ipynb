# %%
"""
    @Author: Manuel Lagunas
    @Personal_page: http://giga.cps.unizar.es/~mlagunas/
    @date: Feb - 2017
"""

import numpy as np
from optim_functions import *

# %matplotlib inline

f_list = [Ackley(),
     Griewank(),
     Beale(),
     Booth(),
     Rothyp(),
     Forrester(),
     Matyas()]

for f in f_list:
    f.plot(samples=100)

# %%
# Out:
# array([3, 2, 1])
